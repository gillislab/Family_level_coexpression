# %%
import pandas as pd 
import Go_annotations
import GO_Enrichment_Calculator
import numpy as np
import Name_resolver
import tqdm as tq
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
matplotlib.rcParams.update(new_rc_params)

# %%
top_groups = pd.read_csv('/data/passala/Post_dump_files/Generated_Tables/Comparing_all_orthogorups_across_plants/Ortho_cross_all_tables/top177_better_ortho_performance_groups.csv', index_col= 0)

# %%
top_groups
# Out:
#               EGAD Species Present  FC Species Present    AVG FC  AVG EGAD  \
# 485653at3193                    13                  10  0.599338  0.879024
# 784291at3193                    14                  11  0.591378  0.904827
# 874520at3193                    15                  11  0.598040  0.967693
# 868593at3193                    15                  12  0.629234  0.762570
# 866254at3193                    15                  12  0.576279  0.677560
# ...                            ...                 ...       ...       ...
# 887584at3193                     8                  10  0.723906  0.995956
# 29923at3193                     11                  12  0.666327  0.539315
# 671526at3193                     4                   9  0.694627  0.844414
# 123690at3193                    10                  11  0.622234  0.979809
# 74616at3193                     13                  11  0.663160  0.854774
#
#              Conservation Between  AVG FC Ortho  FC Species Present Ortho  \
# 485653at3193                Genes      0.866388                        14
# 784291at3193                Genes      0.850309                        14
# 874520at3193                Genes      0.847304                        15
# 868593at3193                Genes      0.875838                        15
# 866254at3193                Genes      0.812831                        15
# ...                           ...           ...                       ...
# 887584at3193                Genes      0.883301                        11
# 29923at3193                 Genes      0.825715                        15
# 671526at3193                Genes      0.853469                        12
# 123690at3193                Genes      0.780878                        15
# 74616at3193                 Genes      0.821578                        15
#
#              Conservation Between Ortho  Gene minus Ortho
# 485653at3193                Orthogroups         -0.267050
# 784291at3193                Orthogroups         -0.258932
# 874520at3193                Orthogroups         -0.249265
# 868593at3193                Orthogroups         -0.246604
# 866254at3193                Orthogroups         -0.236552
# ...                                 ...               ...
# 887584at3193                Orthogroups         -0.159395
# 29923at3193                 Orthogroups         -0.159387
# 671526at3193                Orthogroups         -0.158843
# 123690at3193                Orthogroups         -0.158644
# 74616at3193                 Orthogroups         -0.158418
#
# [177 rows x 9 columns]

# %%
def get_ncbi_clean_og2gene_for_species(species_1, og2genes_only_cococonet, ncbi_mapping):


    species_1_name = Name_resolver.species_name_resolver(species_1,desired_type='common')

    first_species_ortho_groups = og2genes_only_cococonet.loc[og2genes_only_cococonet['Species'] == species_1]
    shared_orthogroups = first_species_ortho_groups['Orthogroup'].unique()

    list_of_orthogene_pds = []
    for orthogroup in tq.tqdm(shared_orthogroups,desc ='inner_loop',position= 0,leave = False):
        species_1_genes = first_species_ortho_groups['Gene'].loc[first_species_ortho_groups['Orthogroup']== orthogroup].to_list()
        all_gene_combos = species_1_genes
        current_orthogroup_pd = pd.DataFrame(columns = [f'{species_1_name} OrthoGene'], data = all_gene_combos)
        current_orthogroup_pd['Orthogroup'] = orthogroup
        list_of_orthogene_pds.append(current_orthogroup_pd)

    final_species_lineup = pd.concat(list_of_orthogene_pds)
    ncbi_added_once = final_species_lineup.merge(right = ncbi_mapping[['Orthodb Gene','Symbol']], right_on = 'Orthodb Gene',left_on=f'{species_1_name} OrthoGene')
    ncbi_added_once_clean= ncbi_added_once.drop(columns = 'Orthodb Gene')
    return ncbi_added_once_clean

# %%
og_groups = pd.read_csv('/data/passala/OrthoDB_data/NCBI_data/og_2_Genes_with_ncbi_symbol.csv')
ncbi_mapping = pd.read_csv('/data/passala/OrthoDB_data/NCBI_data/merged_ncbi_to_orthodb_fixed_non_genesymbol.csv')

# %%
Name_resolver.species_name_resolver('arabidopsis', 'taxa_id')
# Out:
# 3702

# %%
og_groups
# Out:
#           Orthogroup            Gene  Species  Ortholevel    Orthodb Gene  \
# 0       100007at3193   4558_0:003a4f     4558        3193   4558_0:003a4f
# 1       100007at3193   4577_0:004254     4577        3193   4577_0:004254
# 2       100007at3193   4577_0:004e43     4577        3193   4577_0:004e43
# 3       100067at3193   4558_0:00439a     4558        3193   4558_0:00439a
# 4       100085at3193   4558_0:002fd8     4558        3193   4558_0:002fd8
# ...              ...             ...      ...         ...             ...
# 502887    9969at3193  15368_0:000e9a    15368        3193  15368_0:000e9a
# 502888   99917at3193  39947_0:006297    39947        3193  39947_0:006297
# 502889   99917at3193  39947_0:00634f    39947        3193  39947_0:00634f
# 502890   99917at3193  39947_0:006629    39947        3193  39947_0:006629
# 502891   99999at3193  39947_0:006fc4    39947        3193  39947_0:006fc4
#
#               Symbol
# 0       LOC110434333
# 1       LOC100276500
# 2       LOC100275058
# 3         LOC8071983
# 4         LOC8086335
# ...              ...
# 502887  LOC100834561
# 502888  LOC107276177
# 502889    LOC9269479
# 502890    LOC9269626
# 502891        orf173
#
# [502892 rows x 6 columns]

# %%
arabi_gene_lineup = get_ncbi_clean_og2gene_for_species(3702,og_groups,ncbi_mapping)

# %%
top_groups
# Out:
#               EGAD Species Present  FC Species Present    AVG FC  AVG EGAD  \
# 485653at3193                    13                  10  0.599338  0.879024
# 784291at3193                    14                  11  0.591378  0.904827
# 874520at3193                    15                  11  0.598040  0.967693
# 868593at3193                    15                  12  0.629234  0.762570
# 866254at3193                    15                  12  0.576279  0.677560
# ...                            ...                 ...       ...       ...
# 887584at3193                     8                  10  0.723906  0.995956
# 29923at3193                     11                  12  0.666327  0.539315
# 671526at3193                     4                   9  0.694627  0.844414
# 123690at3193                    10                  11  0.622234  0.979809
# 74616at3193                     13                  11  0.663160  0.854774
#
#              Conservation Between  AVG FC Ortho  FC Species Present Ortho  \
# 485653at3193                Genes      0.866388                        14
# 784291at3193                Genes      0.850309                        14
# 874520at3193                Genes      0.847304                        15
# 868593at3193                Genes      0.875838                        15
# 866254at3193                Genes      0.812831                        15
# ...                           ...           ...                       ...
# 887584at3193                Genes      0.883301                        11
# 29923at3193                 Genes      0.825715                        15
# 671526at3193                Genes      0.853469                        12
# 123690at3193                Genes      0.780878                        15
# 74616at3193                 Genes      0.821578                        15
#
#              Conservation Between Ortho  Gene minus Ortho
# 485653at3193                Orthogroups         -0.267050
# 784291at3193                Orthogroups         -0.258932
# 874520at3193                Orthogroups         -0.249265
# 868593at3193                Orthogroups         -0.246604
# 866254at3193                Orthogroups         -0.236552
# ...                                 ...               ...
# 887584at3193                Orthogroups         -0.159395
# 29923at3193                 Orthogroups         -0.159387
# 671526at3193                Orthogroups         -0.158843
# 123690at3193                Orthogroups         -0.158644
# 74616at3193                 Orthogroups         -0.158418
#
# [177 rows x 9 columns]

# %%
genes_in_top_groups = arabi_gene_lineup.loc[arabi_gene_lineup['Orthogroup'].isin(top_groups.index)]

# %%
genes_in_top_groups
# Out:
#       arabidopsis OrthoGene    Orthogroup     Symbol
# 493           3702_0:0000c5  113107at3193  AT1G09550
# 494           3702_0:000460  113107at3193  AT1G57590
# 495           3702_0:0025db  113107at3193  AT2G46930
# 496           3702_0:0038e3  113107at3193  AT3G62060
# 497           3702_0:0039ae  113107at3193  AT3G09405
# ...                     ...           ...        ...
# 25408         3702_0:001ab9  889988at3193  AT1G13635
# 25409         3702_0:001b81  889988at3193  AT1G75090
# 25410         3702_0:003ee2  889988at3193  AT3G12710
# 25411         3702_0:0056b9  889988at3193  AT5G57970
# 25412         3702_0:0061b9  889988at3193  AT5G44680
#
# [937 rows x 3 columns]

# %%
genes_in_top_groups_one_per_group = genes_in_top_groups.sample(frac=1).drop_duplicates(subset = 'Orthogroup')

# %%
genes_in_top_groups_one_per_group
# Out:
#       arabidopsis OrthoGene    Orthogroup     Symbol
# 5922          3702_0:0038b6  272888at3193  AT3G27400
# 4387          3702_0:003d2b  138900at3193  AT3G44220
# 1329          3702_0:00305b  118605at3193  AT3G07380
# 21599         3702_0:002832  877627at3193  AT2G24630
# 16682         3702_0:00094f   72224at3193  AT1G12090
# ...                     ...           ...        ...
# 19296         3702_0:00117f  866942at3193  AT1G02500
# 24583         3702_0:004ced  887584at3193  AT4G36040
# 16796         3702_0:0029b6  728638at3193  AT2G17040
# 15099         3702_0:0043d3  613535at3193  AT4G11170
# 3239          3702_0:002eb2  131275at3193  AT3G16720
#
# [169 rows x 3 columns]

# %%
arabi_go = Go_annotations.get_go_annotations_as_panda('arabidopsis')

# %%
rice_num_terms = arabi_go.sum().T
rice_num_terms = pd.DataFrame(rice_num_terms, columns = ['Number Annotated Genes'])
rice_num_terms
# Out:
#             Number Annotated Genes
# GO_term
# GO:0000002                     5.0
# GO:0000003                  1947.0
# GO:0000009                     3.0
# GO:0000012                     5.0
# GO:0000014                    11.0
# ...                            ...
# GO:2001280                     2.0
# GO:2001289                     9.0
# GO:2001293                     7.0
# GO:2001294                     2.0
# GO:2001295                     5.0
#
# [10704 rows x 1 columns]

# %%
cont_tables = GO_Enrichment_Calculator.generate_contigency_tables(arabi_go, gene_list= genes_in_top_groups_one_per_group['Symbol'].values)

# %%
results_step_1 = GO_Enrichment_Calculator.fishers_exact_on_contigency_tables(cont_tables, arabi_go)

# %%
results_step_1.sort_values(by = 'P_value')
# Out:
#                  P_value
# GO_term
# GO:0050896  8.982156e-09
# GO:0042221  1.079595e-08
# GO:0009506  6.514977e-08
# GO:0055044  6.626412e-08
# GO:0070161  6.626412e-08
# ...                  ...
# GO:0016128  1.000000e+00
# GO:0016129  1.000000e+00
# GO:0016131  1.000000e+00
# GO:0016137  1.000000e+00
# GO:2001295  1.000000e+00
#
# [10704 rows x 1 columns]

# %%
corrected_results = GO_Enrichment_Calculator.multi_hypothesis_correct_fishers_exact(results_step_1)

# %%
corrected_results['Number Annotated Genes'] = rice_num_terms['Number Annotated Genes']

# %%
corrected_results.sort_values(by = 'P_value').head(50)
# Out:
#              P_value  Number Annotated Genes
# GO_term
# GO:0050896  0.000058                  7027.0
# GO:0042221  0.000058                  3515.0
# GO:0005911  0.000103                  1060.0
# GO:0070161  0.000103                  1060.0
# GO:0009506  0.000103                  1059.0
# GO:0030054  0.000103                  1061.0
# GO:0055044  0.000103                  1060.0
# GO:0010200  0.000202                   144.0
# GO:0010033  0.000202                  2307.0
# GO:0010243  0.000202                   294.0
# GO:0005976  0.000275                   500.0
# GO:0005975  0.000305                  1163.0
# GO:0009628  0.000329                  2403.0
# GO:0071554  0.000428                   759.0
# GO:1901700  0.000507                  1811.0
# GO:0071944  0.000507                  4695.0
# GO:0016051  0.000507                   340.0
# GO:0042493  0.000507                   700.0
# GO:0009719  0.000634                  1958.0
# GO:0003824  0.000897                 10101.0
# GO:1901698  0.000897                   366.0
# GO:0005618  0.000897                   826.0
# GO:0030312  0.000897                   828.0
# GO:0070887  0.001489                  1742.0
# GO:0006950  0.001489                  3997.0
# GO:0000271  0.002445                   218.0
# GO:0009725  0.002765                  1921.0
# GO:0034637  0.002929                   225.0
# GO:0042546  0.004900                   241.0
# GO:0044264  0.005275                   308.0
# GO:0044262  0.009876                   481.0
# GO:0045229  0.011116                   654.0
# GO:0043565  0.011909                  1333.0
# GO:0001101  0.012737                  1342.0
# GO:0009611  0.018601                   227.0
# GO:0016757  0.019276                   696.0
# GO:0048364  0.019718                   528.0
# GO:0071555  0.019718                   612.0
# GO:0022622  0.019913                   530.0
# GO:0016758  0.021498                   454.0
# GO:0071310  0.021604                  1200.0
# GO:0033692  0.025604                   182.0
# GO:0044036  0.025604                   182.0
# GO:0003700  0.026640                  1661.0
# GO:0010035  0.027363                  1025.0
# GO:0009723  0.034227                   329.0
# GO:0009873  0.038248                   197.0
# GO:0071495  0.045071                  1075.0
# GO:0110165  0.045528                 25829.0
# GO:0046677  0.047791                   348.0

# %%
all_go_terms = pd.read_csv('/home/passala/Gene_duplication_project/Data_from_others/go_terms.txt',sep = '\t')

# %%
named_go = corrected_results.merge(right = all_go_terms, left_index=True, right_index= True)

# %%
named_go
# Out:
#             P_value  Number Annotated Genes  \
# GO:0000002      1.0                     5.0
# GO:0000003      1.0                  1947.0
# GO:0000009      1.0                     3.0
# GO:0000012      1.0                     5.0
# GO:0000014      1.0                    11.0
# ...             ...                     ...
# GO:2001280      1.0                     2.0
# GO:2001289      1.0                     9.0
# GO:2001293      1.0                     7.0
# GO:2001294      1.0                     2.0
# GO:2001295      1.0                     5.0
#
#                                                          Name
# GO:0000002                   mitochondrial genome maintenance
# GO:0000003                                       reproduction
# GO:0000009             alpha-1,6-mannosyltransferase activity
# GO:0000012                         single strand break repair
# GO:0000014  single-stranded DNA endodeoxyribonuclease acti...
# ...                                                       ...
# GO:2001280  positive regulation of unsaturated fatty acid ...
# GO:2001289                          lipid X metabolic process
# GO:2001293                      malonyl-CoA metabolic process
# GO:2001294                      malonyl-CoA catabolic process
# GO:2001295                   malonyl-CoA biosynthetic process
#
# [10677 rows x 3 columns]

# %%
top_40_go = named_go.sort_values(by = 'P_value').loc[named_go['Number Annotated Genes']<300].head(40)

# %%
top_40_go['Neg Log P Val'] =-1* np.log10(top_40_go['P_value'])
top_40_go.head()
# Out:
#              P_value  Number Annotated Genes  \
# GO:0010243  0.000202                   294.0
# GO:0010200  0.000202                   144.0
# GO:0000271  0.002445                   218.0
# GO:0034637  0.002929                   225.0
# GO:0042546  0.004900                   241.0
#
#                                                   Name  Neg Log P Val
# GO:0010243         response to organonitrogen compound       3.695677
# GO:0010200                          response to chitin       3.695677
# GO:0000271         polysaccharide biosynthetic process       2.611784
# GO:0034637  cellular carbohydrate biosynthetic process       2.533270
# GO:0042546                        cell wall biogenesis       2.309832

# %%
top_40_go.head(9)
# Out:
#              P_value  Number Annotated Genes  \
# GO:0010243  0.000202                   294.0
# GO:0010200  0.000202                   144.0
# GO:0000271  0.002445                   218.0
# GO:0034637  0.002929                   225.0
# GO:0042546  0.004900                   241.0
# GO:0009611  0.018601                   227.0
# GO:0033692  0.025604                   182.0
# GO:0044036  0.025604                   182.0
# GO:0009873  0.038248                   197.0
#
#                                                     Name  Neg Log P Val
# GO:0010243           Response to organonitrogen compound       3.695677
# GO:0010200                            Response to chitin       3.695677
# GO:0000271           Polysaccharide biosynthetic process       2.611784
# GO:0034637    Cellular carbohydrate biosynthetic process       2.533270
# GO:0042546                          Cell wall biogenesis       2.309832
# GO:0009611                          Response to wounding       1.730461
# GO:0033692  Cellular polysaccharide biosynthetic process       1.591685
# GO:0044036     Cell wall macromolecule metabolic process       1.591685
# GO:0009873          Ethylene-activated signaling pathway       1.417391

# %%
top_40_go['Name'] = top_40_go['Name'].str.capitalize()
top_40_go
# Out:
#              P_value  Number Annotated Genes  \
# GO:0010243  0.000202                   294.0
# GO:0010200  0.000202                   144.0
# GO:0000271  0.002445                   218.0
# GO:0034637  0.002929                   225.0
# GO:0042546  0.004900                   241.0
# GO:0009611  0.018601                   227.0
# GO:0033692  0.025604                   182.0
# GO:0044036  0.025604                   182.0
# GO:0009873  0.038248                   197.0
# GO:0010383  0.059148                   152.0
# GO:0071369  0.064091                   218.0
# GO:0006073  0.069434                   223.0
# GO:0044042  0.073442                   229.0
# GO:0010410  0.081606                   111.0
# GO:0015840  0.081606                     6.0
# GO:0071918  0.081606                     6.0
# GO:0015204  0.081606                     6.0
# GO:0047262  0.083009                    27.0
# GO:0009250  0.111805                   122.0
# GO:0000160  0.119822                   258.0
# GO:0019755  0.153900                     9.0
# GO:0010015  0.156067                   275.0
# GO:1900055  0.219407                    41.0
# GO:1900056  0.251612                    12.0
# GO:0010413  0.251612                    12.0
# GO:0010417  0.251612                    12.0
# GO:0009751  0.269342                   230.0
# GO:0002239  0.283721                    97.0
# GO:0046527  0.315246                   239.0
# GO:1905622  0.316738                    14.0
# GO:0010119  0.331917                   103.0
# GO:0009630  0.350833                   106.0
# GO:0046658  0.353926                   174.0
# GO:0072330  0.354219                   251.0
# GO:0008559  0.363579                    16.0
# GO:0045489  0.365364                    54.0
# GO:0004805  0.399953                    17.0
# GO:0045491  0.411223                    57.0
# GO:0070482  0.422792                   271.0
# GO:0010393  0.422792                   192.0
#
#                                                          Name  Neg Log P Val
# GO:0010243                Response to organonitrogen compound       3.695677
# GO:0010200                                 Response to chitin       3.695677
# GO:0000271                Polysaccharide biosynthetic process       2.611784
# GO:0034637         Cellular carbohydrate biosynthetic process       2.533270
# GO:0042546                               Cell wall biogenesis       2.309832
# GO:0009611                               Response to wounding       1.730461
# GO:0033692       Cellular polysaccharide biosynthetic process       1.591685
# GO:0044036          Cell wall macromolecule metabolic process       1.591685
# GO:0009873               Ethylene-activated signaling pathway       1.417391
# GO:0010383         Cell wall polysaccharide metabolic process       1.228061
# GO:0071369             Cellular response to ethylene stimulus       1.193202
# GO:0006073                  Cellular glucan metabolic process       1.158428
# GO:0044042                           Glucan metabolic process       1.134054
# GO:0010410                    Hemicellulose metabolic process       1.088277
# GO:0015840                                     Urea transport       1.088277
# GO:0071918                       Urea transmembrane transport       1.088277
# GO:0015204            Urea transmembrane transporter activity       1.088277
# GO:0047262  Polygalacturonate 4-alpha-galacturonosyltransf...       1.080874
# GO:0009250                        Glucan biosynthetic process       0.951539
# GO:0000160            Phosphorelay signal transduction system       0.921464
# GO:0019755                      One-carbon compound transport       0.812762
# GO:0010015                                 Root morphogenesis       0.806690
# GO:1900055                      Regulation of leaf senescence       0.658749
# GO:1900056             Negative regulation of leaf senescence       0.599269
# GO:0010413                   Glucuronoxylan metabolic process       0.599269
# GO:0010417                Glucuronoxylan biosynthetic process       0.599269
# GO:0009751                         Response to salicylic acid       0.569696
# GO:0002239                              Response to oomycetes       0.547108
# GO:0046527                       Glucosyltransferase activity       0.501350
# GO:1905622            Negative regulation of leaf development       0.499299
# GO:0010119                    Regulation of stomatal movement       0.478971
# GO:0009630                                       Gravitropism       0.454900
# GO:0046658              Anchored component of plasma membrane       0.451087
# GO:0072330           Monocarboxylic acid biosynthetic process       0.450728
# GO:0008559  Atpase-coupled xenobiotic transmembrane transp...       0.439401
# GO:0045489                        Pectin biosynthetic process       0.437274
# GO:0004805                     Trehalose-phosphatase activity       0.397991
# GO:0045491                            Xylan metabolic process       0.385922
# GO:0070482                          Response to oxygen levels       0.373873
# GO:0010393                     Galacturonan metabolic process       0.373873

# %%
fig, ax = plt.subplots(figsize = (2.5,7))
fig.patch.set_facecolor('white')
g = sns.barplot(data = top_40_go.head(9), x = 'Neg Log P Val',y = 'Name', color = 'tab:green')
#plt.ylabel("Euclidian Distance of Coexpressalog from Target Gene", fontsize = 15)
plt.xlabel("-log10(p value)", fontsize = 14)
g.set(ylabel=None)
#sns.despine()
g.bar_label(g.containers[0], fmt='%.2f', label_type='center')

g.grid(False)
g.spines["bottom"].set_color("black")
g.spines["left"].set_color("black")
g.spines["top"].set_color("black")
g.spines["right"].set_color("black")
#ax.set_xscale('log')
#plt.xlim((-7,7))
# plt.ylim((0, 1250))
#plt.title("Current Threshold is 31", fontsize = 20)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 10)
plt.savefig('/data/passala/Plots_for_projects/Cross_species_go_groups/Go_groups_enrich/go_group_enrichment.pdf',bbox_inches = 'tight')
